# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# %matplotlib inline
# Out:
# C:\Users\demongking28\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
with tf.Session() as sess:
    
    saver=tf.train.import_meta_graph("c:/users/demongking28/models/new_model.ckpt.meta")
    saver.restore(sess,tf.train.latest_checkpoint('c:/users/demongking28/models/'))
    
    restored_m=sess.run("w1:0")
    restored_b=sess.run("w2:0")
# Out:
# INFO:tensorflow:Restoring parameters from c:/users/demongking28/models/new_model.ckpt

# %%
print(restored_m)
print(restored_b)
# Out:
# 2.0509592498367923
# 0.8832140480122509
